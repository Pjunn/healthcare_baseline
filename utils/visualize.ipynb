# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image 
import json

# %%
image_path = "../image/image/front_8.png"
Image.open(image_path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1920x897>

# %%
json_path="../image/json/front_8.json"

with open(json_path) as f:
    json_object = json.load(f)

for tooth in json_object['tooth']:
